# %% [markdown]
# # Handle Missing values in pandas

# %%
import pandas as pd

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# **NaN stands for "Not a Number" and indicates missing value.
# NaN is not a string ,rather it's a special value : numpy.nan**

# %%
# isnull/isna return a dataframe with booleans(True if missing ,False in not missing)
ufo.isnull().head()   #both codes are same
ufo.isna().head()
# Out:
#     City  Colors Reported  Shape Reported  State   Time
# 0  False             True           False  False  False
# 1  False             True           False  False  False
# 2  False             True           False  False  False
# 3  False             True           False  False  False
# 4  False             True           False  False  False

# %%
#notnull/notna return opposite of isnull/isna (True if not missing ,False if missing)
ufo.notnull().head() 
ufo.notna().head()
# Out:
#    City  Colors Reported  Shape Reported  State  Time
# 0  True            False            True   True  True
# 1  True            False            True   True  True
# 2  True            False            True   True  True
# 3  True            False            True   True  True
# 4  True            False            True   True  True

# %%
#count the no. of missing values in each series
ufo.isnull().sum(axis = 0) #bydefault axis is 0
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
#return a dataframe which have City colunms having NaN values
ufo[ufo['City'].isnull()].head()    #helps to filter the dataframe
# Out:
#     City Colors Reported Shape Reported State             Time
# 21   NaN             NaN            NaN    LA   8/15/1943 0:00
# 22   NaN             NaN          LIGHT    LA   8/15/1943 0:00
# 204  NaN             NaN           DISK    CA  7/15/1952 12:30
# 241  NaN            BLUE           DISK    MT   7/4/1953 14:00
# 613  NaN             NaN           DISK    NV   7/1/1960 12:00

# %%
#return a dataframe which have Colors Reported colunms having not NaN values
ufo[ufo['Colors Reported'].notnull()].head()
# Out:
#           City Colors Reported Shape Reported State             Time
# 12      Belton             RED         SPHERE    SC  6/30/1939 20:00
# 19  Bering Sea             RED          OTHER    AK  4/30/1943 23:00
# 36  Portsmouth             RED      FORMATION    VA   7/10/1945 1:30
# 44   Blairsden           GREEN         SPHERE    CA  6/30/1946 19:00
# 66     Wexford            BLUE            NaN    PA   7/1/1947 20:00

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
#if 'any' value is missing in the row ,then drop that row
ufo.dropna(how = "any").shape
# Out:
# (2486, 5)

# %%
#'inplace' parameter for 'dropna' is False by default, thus rows were only dropped temporarily
ufo.shape
# Out:
# (18241, 5)

# %%
#if 'all' value is missing in the row ,then drop that row
ufo.dropna(how = "all").shape
# Out:
# (18241, 5)

# %%
#if 'any' value is missing in the row(City and Shape Reported) ,then drop that row
ufo.dropna(subset = ['City','Shape Reported'] , how = "any").shape
# Out:
# (15576, 5)

# %%
#if 'all' value is missing in the row(City and Shape Reported) ,then drop that row
ufo.dropna(subset = ['City','Shape Reported'] , how = "all").shape
# Out:
# (18237, 5)

# %%
#value_counts does not show the count of missing value by default
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# PYRAMID         1
# DOME            1
# HEXAGON         1
# FLARE           1
# Name: Shape Reported, dtype: int64

# %%
#explicitly include missing value
ufo['Shape Reported'].value_counts(dropna = False).head()
# Out:
# LIGHT       2803
# NaN         2644
# DISK        2122
# TRIANGLE    1889
# OTHER       1402
# Name: Shape Reported, dtype: int64

# %%
#fill missing value with some specific value
ufo['Shape Reported'].fillna(value = "OTHER", inplace = True)

# %%
#check the missing value filled 
ufo['Shape Reported'].value_counts().head()
# Out:
# OTHER       4046
# LIGHT       2803
# DISK        2122
# TRIANGLE    1889
# CIRCLE      1365
# Name: Shape Reported, dtype: int64

# %% [markdown]
# **Question** : In Some Scenarios instead of NaN, will be having Zero. How do you handle those or how you will count number of Zeros?
#
# **Answer Code** : df["colum_name"].replace(0, np.nan, inplace = True)

# %% [markdown]
# # Create dummy variables in pandas

# %%
train = pd.read_csv('http://bit.ly/kaggletrain')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#using map method, create 'Sex_male' dummy variable
train['Sex_male'] = train['Sex'].map({'male':1, 'female': 0})

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Sex_male
# 0      0         A/5 21171   7.2500   NaN        S         1
# 1      0          PC 17599  71.2833   C85        C         0
# 2      0  STON/O2. 3101282   7.9250   NaN        S         0
# 3      0            113803  53.1000  C123        S         0
# 4      0            373450   8.0500   NaN        S         1

# %%
#alternative: use 'get_dummies' to create one column for every possible value
pd.get_dummies(train['Sex']).head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %% [markdown]
# If you have **'K' possible values** for categorial feature , then you only need **K-1 dummy variables** to capture all the information about that feature.

# %%
# drop the first column using iloc
#add prefix to identify the source of summy variable
pd.get_dummies(train['Sex'], prefix ='Sex').iloc[:,1:]
# Out:
#      Sex_male
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1
# ..        ...
# 886         1
# 887         0
# 888         0
# 889         1
# 890         1
#
# [891 rows x 1 columns]

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
# use "get dummies" with a feature that has 3 possible value and then drop the 1st dummy column using 'iloc'
pd.get_dummies(train['Embarked'], prefix = 'Embarked').iloc[:,1:]
# Out:
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# ..          ...         ...
# 886           0           1
# 887           0           1
# 888           0           1
# 889           0           0
# 890           1           0
#
# [891 rows x 2 columns]

# %%
#save the dataframe of dummy variable and concatenate with the original dataframe
dummies_column =pd.get_dummies(train['Embarked'], prefix = 'Embarked').iloc[:,1:]
train = pd.concat([train,dummies_column], axis =1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Sex_male  Embarked_Q  \
# 0      0         A/5 21171   7.2500   NaN        S         1           0
# 1      0          PC 17599  71.2833   C85        C         0           0
# 2      0  STON/O2. 3101282   7.9250   NaN        S         0           0
# 3      0            113803  53.1000  C123        S         0           0
# 4      0            373450   8.0500   NaN        S         1           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
#reset the dataframe
train = pd.read_csv('http://bit.ly/kaggletrain')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **A super easy way to create and concatenate dummy variable to original dataframe**

# %%
#pass the Dataframe to 'get_dummies' and specify which columns to dummy(it drops the original columns )
pd.get_dummies(train, columns = ['Sex','Embarked']).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin  Sex_female  Sex_male  Embarked_C  \
# 0         A/5 21171   7.2500   NaN           0         1           0
# 1          PC 17599  71.2833   C85           1         0           1
# 2  STON/O2. 3101282   7.9250   NaN           1         0           0
# 3            113803  53.1000  C123           1         0           0
# 4            373450   8.0500   NaN           0         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
#use the "drop_first" parameter to drop the first dummy variable for each feature
pd.get_dummies(train, columns = ['Sex','Embarked'], drop_first = True).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin  Sex_male  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500   NaN         1           0           1
# 1          PC 17599  71.2833   C85         0           0           0
# 2  STON/O2. 3101282   7.9250   NaN         0           0           1
# 3            113803  53.1000  C123         0           0           1
# 4            373450   8.0500   NaN         1           0           1

# %% [markdown]
# # find and remove duplicate rows in pandas

# %%
user_cols = ['user_id','age','sex','occupation','zipcode']
users = pd.read_table('http://bit.ly/movieusers',sep = '|',header = None ,names = user_cols, index_col = 0)
users.head()
# Out:
#          age sex  occupation zipcode
# user_id
# 1         24   M  technician   85711
# 2         53   F       other   94043
# 3         23   M      writer   32067
# 4         24   M  technician   43537
# 5         33   F       other   15213

# %%
users.shape
# Out:
# (943, 4)

# %%
# detect the duplicated zip code : True if an item is identical to previous item
users['zipcode'].duplicated().tail()
# Out:
# user_id
# 939    False
# 940     True
# 941    False
# 942    False
# 943    False
# Name: zipcode, dtype: bool

# %%
#count the duplicated zipcode
users['zipcode'].duplicated().sum()
# Out:
# 148

# %%
#check the no. of duplicated rows
users.duplicated().sum()
# Out:
# 7

# %% [markdown]
# **Logic for duplicated**
#    - **keep = 'first'** :(default) Mark duplicates as True (except the first value)
#    - **keep = 'last'** : Mark duplicates as True (except the last value)
#    - **keep = False** : Mark all duplicates as True

# %%
# examine the duplicated rows (ignoring the first occurance)
users.loc[users.duplicated(keep = 'first'),:]
# Out:
#          age sex occupation zipcode
# user_id
# 496       21   F    student   55414
# 572       51   M   educator   20003
# 621       17   M    student   60402
# 684       28   M    student   55414
# 733       44   F      other   60630
# 805       27   F      other   20009
# 890       32   M    student   97301

# %%
# examine the duplicated rows (ignoring the last occurance)
users.loc[users.duplicated(keep = 'last'),:]
# Out:
#          age sex occupation zipcode
# user_id
# 67        17   M    student   60402
# 85        51   M   educator   20003
# 198       21   F    student   55414
# 350       32   M    student   97301
# 428       28   M    student   55414
# 437       27   F      other   20009
# 460       44   F      other   60630

# %%
users.loc[users.duplicated(keep = False), :]
# Out:
#          age sex occupation zipcode
# user_id
# 67        17   M    student   60402
# 85        51   M   educator   20003
# 198       21   F    student   55414
# 350       32   M    student   97301
# 428       28   M    student   55414
# 437       27   F      other   20009
# 460       44   F      other   60630
# 496       21   F    student   55414
# 572       51   M   educator   20003
# 621       17   M    student   60402
# 684       28   M    student   55414
# 733       44   F      other   60630
# 805       27   F      other   20009
# 890       32   M    student   97301

# %%
#drop the duplicated rows(inplace is False by default)
users.drop_duplicates(keep = 'first').shape
# Out:
# (936, 4)

# %%
users.drop_duplicates(keep = 'last').shape
# Out:
# (936, 4)

# %%
users.drop_duplicates(keep = False).shape
# Out:
# (929, 4)

# %%
# count the no. of duplicates, only consider a subset of column when identifying the duplicates
users.duplicated(subset = ['age','zipcode']).sum()
# Out:
# 16

# %%
# return the dataframe that contains duplicated rows
users[users.duplicated(subset = ['age','zipcode'])]
# Out:
#          age sex     occupation zipcode
# user_id
# 84        32   M      executive   55369
# 496       21   F        student   55414
# 567       24   M  entertainment   10003
# 572       51   M       educator   20003
# 621       17   M        student   60402
# 630       26   F     healthcare   55408
# 634       39   M       engineer   T8H1N
# 684       28   M        student   55414
# 703       26   M       educator   49512
# 733       44   F          other   60630
# 741       25   M         writer   63108
# 773       20   M        student   55414
# 777       63   M     programmer   01810
# 805       27   F          other   20009
# 890       32   M        student   97301
# 898       23   M      homemaker   61755

# %%
# return the dataframe that does NOT contains duplicated rows
users[~users.duplicated(subset = ['age','zipcode'])]
# Out:
#          age sex     occupation zipcode
# user_id
# 1         24   M     technician   85711
# 2         53   F          other   94043
# 3         23   M         writer   32067
# 4         24   M     technician   43537
# 5         33   F          other   15213
# ...      ...  ..            ...     ...
# 939       26   F        student   33319
# 940       32   M  administrator   02215
# 941       20   M        student   97229
# 942       48   F      librarian   78209
# 943       22   M        student   77841
#
# [927 rows x 4 columns]

# %%
#drop the duplicates of the subset column
users.drop_duplicates(subset = ['age','zipcode']).shape
# Out:
# (927, 4)
