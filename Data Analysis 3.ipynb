# %% [markdown]
# # Sort pandas Dataframe or a series

# %%
import pandas as pd

# %%
movies = pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
#sort 'genre' series in alphabetically descending order
movies['genre'].sort_values(ascending = False)
# Out:
# 704    Western
# 421    Western
# 119    Western
# 236    Western
# 263    Western
#         ...
# 871     Action
# 129     Action
# 619     Action
# 753     Action
# 152     Action
# Name: genre, Length: 979, dtype: object

# %%
#sort movies dataframe by a series ('duration') in decresing length
movies.sort_values('duration',ascending = False)
# Out:
#      star_rating                              title content_rating      genre  \
# 476          7.8                             Hamlet          PG-13      Drama
# 157          8.2                 Gone with the Wind              G      Drama
# 78           8.4        Once Upon a Time in America              R      Crime
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# ..           ...                                ...            ...        ...
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 338          8.0                Battleship Potemkin        UNRATED    History
# 389          8.0                             Freaks        UNRATED      Drama
#
# ...

# %%
#sort dataframe by two columns (first by 'content rating' and then by 'duration') 
movies.sort_values(['content_rating','duration'], ascending =[True,False])
# Out:
#      star_rating                               title content_rating  \
# 445          7.9                The Ten Commandments       APPROVED
# 767          7.6     It's a Mad, Mad, Mad, Mad World       APPROVED
# 444          7.9                        My Fair Lady       APPROVED
# 557          7.8                        Mary Poppins       APPROVED
# 95           8.4                       All About Eve       APPROVED
# ..           ...                                 ...            ...
# 913          7.5                            Suspiria              X
# 486          7.8                        Evil Dead II              X
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
#
#          genre  duration                                        actors_list
# ...

# %% [markdown]
# # Filter rows of a pandas dataframe by column value

# %%
movies = pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
##filer dataframe with single condition :
#filter dataframe which have duration of the movie greater than and equal to 200 and genre  should be adventure
movies[movies['duration'] >= 200 ]  #output a filter dataframe
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
##filter dataframe with multiple condition :
#filter dataframe having duration greater than 200 and genre should be 'Adventure'
movies[(movies['duration'] >= 200) & (movies['genre'] == 'Adventure')]    # &  and operator
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 85              PG  Adventure       216
# 142             PG  Adventure       224
# 204              G  Adventure       212
# 445       APPROVED  Adventure       220
#
#                                            actors_list
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 85   [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 204  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 445  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...

# %%
#filter rows having genre 'Adventure','Drama','Action'
movies[(movies['genre'] == 'Adventure') | (movies['genre'] == 'Drama') | (movies['genre'] == 'Action') ] # |  or operator
movies[movies['genre'].isin(['Adventure','Drama','Action'])]   #both code return the same value
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 5            8.9                                       12 Angry Men
# 7            8.9      The Lord of the Rings: The Return of the King
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# ..           ...                                                ...
# 970          7.4                                        Wonder Boys
# 972          7.4                                     Blue Valentine
# 973          7.4                              The Cider House Rules
# 975          7.4                        Back to the Future Part III
# 976          7.4    Master and Commander: The Far Side of the World
#
#     content_rating      genre  duration  \
# 3            PG-13     Action       152
# 5        NOT RATED      Drama        96
# ...

# %% [markdown]
# # Explore pandas series

# %%
movies = pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
#returns the data type of each column
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies['genre'].describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
# return the frequency of each class
movies['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
# returns a value counts of those greater than 100
movies['genre'].value_counts()[movies['genre'].value_counts() > 100]
# Out:
# Drama     278
# Comedy    156
# Action    136
# Crime     124
# Name: genre, dtype: int64

# %%
#return the % of each class
movies['genre'].value_counts(normalize = True)
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Sci-Fi       0.005107
# Thriller     0.005107
# Film-Noir    0.003064
# Family       0.002043
# Fantasy      0.001021
# History      0.001021
# Name: genre, dtype: float64

# %%
# return the name of unique class
movies['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
#retuen the no. of unique class
movies['genre'].nunique()
# Out:
# 16

# %%
# returns the tally of the two series to be given in the argument
pd.crosstab(movies['genre'],movies['content_rating'])
# Out:
# content_rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# ...

# %%
# %matplotlib inline
movies['genre'].value_counts().plot(kind = 'bar')
